# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Dataset

# %%
df = pd.read_csv('Automobile_data.csv')

# %% [markdown]
# first 5 rows of datasets

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# show the full datasets

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# shape of the dataset

# %%
df.shape
# Out:
# (205, 26)

# %% [markdown]
# columns

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
#identify missing values
#deal with missing data
#correct the data format

# %% [markdown]
# info of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# Replace null values

# %%
df= df.replace('?', np.nan)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
missing_data = df.isnull()
missing_data.head()
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False               True  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %%
for column in missing_data.columns:
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# symboling
# symboling
# False    205
# Name: count, dtype: int64
#
# normalized-losses
# normalized-losses
# False    164
# True      41
# Name: count, dtype: int64
#
# make
# make
# False    205
# Name: count, dtype: int64
#
# fuel-type
# fuel-type
# False    205
# Name: count, dtype: int64
#
# aspiration
# aspiration
# False    205
# Name: count, dtype: int64
#
# num-of-doors
# num-of-doors
# False    203
# True       2
# Name: count, dtype: int64
#
# body-style
# body-style
# False    205
# Name: count, dtype: int64
#
# drive-wheels
# drive-wheels
# False    205
# Name: count, dtype: int64
#
# engine-location
# engine-location
# False    205
# Name: count, dtype: int64
#
# wheel-base
# wheel-base
# False    205
# Name: count, dtype: int64
#
# length
# length
# False    205
# Name: count, dtype: int64
#
# width
# width
# False    205
# Name: count, dtype: int64
#
# height
# height
# False    205
# Name: count, dtype: int64
#
# curb-weight
# curb-weight
# False    205
# ...

# %%
#1.normalized-losses:41 missing data
#2.num of doors:2 missing data
#3.bore:4 missing data
#4.stroke:4 missing data
#5.horsepower:2 missing data
#6.price:4 missing data
#7.peak-rpm:2 missing data

# %%
#1 drop the data
#a) drop the whole row
#b) drop the whole column
#2 replace the data
#a) replace with mean/median/mode

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
#1.normalized-losses:41 missing data- mean
#2.num of doors:2 missing data- frequency-mode
#3.bore:4 missing data- mean
#4.stroke:4 missing data- mean
#5.horsepower:2 missing data- mean
#6.price:4 missing data- drop the 4 rows
#7.peak-rpm:2 missing data- mean

# %%
#calculate the avg of column
avg_norm_loss = df['normalized-losses'].astype('float').mean(axis=0)
print("Average of normalized-losses:", avg_norm_loss)
# Out:
# Average of normalized-losses: 122.0

# %%
#replace NAN WITH avg value
df['normalized-losses'].replace(np.nan, avg_norm_loss, inplace=True)
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_15756\2934262551.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['normalized-losses'].replace(np.nan, avg_norm_loss, inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
#calculate the avg of column
avg_bore = df['bore'].astype('float').mean(axis=0)
print("Average of bore:", avg_bore)
# Out:
# Average of bore: 3.3297512437810943

# %%
df['bore'].replace(np.nan, avg_bore, inplace=True)
df.isnull().sum()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_15756\2864322831.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bore'].replace(np.nan, avg_bore, inplace=True)
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# ...

# %%
#calculate the avg of column
avg_stroke = df['stroke'].astype('float').mean(axis=0)
print("Average of stroke:", avg_stroke)
# Out:
# Average of stroke: 3.255422885572139

# %%
df['stroke'].replace(np.nan, avg_stroke, inplace= True)
df.isnull().sum()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_15756\1668449647.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['stroke'].replace(np.nan, avg_stroke, inplace= True)
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# ...

# %%
#calculate the avg of column
avg_horsepower = df['horsepower'].astype('float').mean(axis=0)
print("Average of horsepower:", avg_horsepower)
# Out:
# Average of horsepower: 104.25615763546799

# %%
df['horsepower'].replace(np.nan, avg_horsepower, inplace= True)
df.isnull().sum()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_15756\193884956.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['horsepower'].replace(np.nan, avg_horsepower, inplace= True)
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# ...

# %%
#calculate the avg of column
avg_peak_rpm = df['peak-rpm'].astype('float').mean(axis=0)
print("Average of peak-rpm:", avg_peak_rpm)
# Out:
# Average of peak-rpm: 5125.369458128079

# %%
df['peak-rpm'].replace(np.nan, avg_peak_rpm, inplace = True)
df.isnull().sum()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_15756\3187513688.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['peak-rpm'].replace(np.nan, avg_peak_rpm, inplace = True)
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# ...

# %%
#frrequency of no_of_doors
df['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    114
# two      89
# Name: count, dtype: int64

# %%
df['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
df['num-of-doors'].replace(np.nan, 'four', inplace = True)
df.isnull().sum()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_15756\3339469392.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['num-of-doors'].replace(np.nan, 'four', inplace = True)
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# ...

# %%
df.dropna(subset=['price'], axis=0, inplace = True)
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 196         -1                95        volvo       gas        std
# 197         -1                95        volvo       gas      turbo
# 198         -1                95        volvo       gas        std
# 199         -1                95        volvo    diesel      turbo
# 200         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
#convert the data type to proper format
df[['bore','stroke','normalized-losses','price','peak-rpm','horsepower']] = df[['bore','stroke','normalized-losses','price','peak-rpm','horsepower']].astype('float')

# %%
df['normalized-losses']= df['normalized-losses'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
#df['num-of-cylinders'].value_counts()
df['num-of-cylinders'].unique().tolist()
# Out:
# ['four', 'six', 'five', 'three', 'twelve', 'two', 'eight']

# %% [markdown]
# ### data cleaning is done

# %% [markdown]
# ### Data standardization

# %%
 #convert mpg to L/100km
df['city-L/100km'] = 235/df['city-mpg']
df['highway-L/100'] = 235/df['highway-mpg']

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    bore  stroke  compression-ratio  horsepower peak-rpm city-mpg  highway-mpg  \
# ...

# %%
df[['length', 'width', 'height']].head()
# Out:
#    length  width  height
# 0   168.8   64.1    48.8
# 1   168.8   64.1    48.8
# 2   171.2   65.5    52.4
# 3   176.6   66.2    54.3
# 4   176.6   66.4    54.3

# %%
### data normalization
# normalization is the pricess of transforming values of several variables into a small range such as 0 to 1 or -1 to 1
# replacing original value/max value

# %%
df['length'] = df['length']/df['length'].max()
df['width'] = df['width']/df['width'].max()
df['height'] = df['height']/df['height'].max()

# %%
df[['length', 'width', 'height']].head()
# Out:
#      length     width    height
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %%
df['horsepower']
# Out:
# 0      111.0
# 1      111.0
# 2      154.0
# 3      102.0
# 4      115.0
#        ...
# 196    114.0
# 197    160.0
# 198    134.0
# 199    106.0
# 200    114.0
# Name: horsepower, Length: 201, dtype: float64

# %%
#binning is a process of transforming data continous numerical variables into discreate catogriocal bins for grouped analysis
df['horsepower']=df['horsepower'].astype(int, copy=True)
plt.hist(df['horsepower'])
#set x and y labels and title
plt.xlabel('horsepower')
plt.ylabel('count')
plt.title('horsepower bins')
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
bins = np.linspace(min(df['horsepower']), max(df['horsepower']), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
#set the names for four bins
group_names = ['Low', 'Medium', 'High']
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True)

# %%
df['horsepower-binned'].value_counts()
# Out:
# horsepower-binned
# Low       153
# Medium     43
# High        5
# Name: count, dtype: int64

# %%
plt.bar(group_names, df['horsepower-binned'].value_counts())
plt.xlabel('horsepower')
plt.ylabel('count')
plt.title('horsepower bins')
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    stroke  compression-ratio  horsepower  peak-rpm city-mpg highway-mpg  \
# ...

# %%
plt.hist(df['horsepower-binned'], bins = 3)
# Out:
# (array([153.,  43.,   5.]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <BarContainer object of 3 artists>)

# %%
#indicator variables/dummy variables
#is a numerical variables used to label catoggories
dummy_variable_1 = pd.get_dummies(df['fuel-type'])
dummy_variable_1.sample(5)
# Out:
#      diesel   gas
# 62    False  True
# 88    False  True
# 35    False  True
# 143   False  True
# 61    False  True

# %%
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'},inplace= True)
dummy_variable_1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0             False           True
# 1             False           True
# 2             False           True
# 3             False           True
# 4             False           True

# %%
#merge data frame "df" and "dummy_variable_1"
df = pd.concat([df, dummy_variable_1], axis = 1)
# drop original column "fuel-type" from "df"
df.drop('fuel-type', axis = 1, inplace= True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    horsepower  peak-rpm  city-mpg highway-mpg    price  city-L/100km  \
# ...

# %%
#cp sp profit
#60 80 20
#80 115 35
#multicolinarity is a condtion in linear regression where independent variables are highly correlates,
#meaining one can be linearly predicated from the others

# %%
#This condition can make it difficult for a model to estimate the unique effect of each independent variable
#leading to unstable and imprecise coefficient estimates.
#it can be identified by high R-squared values alongside few siginificant regression parameters or high varience inflation factor

# %%
df['aspiration'].value_counts()
# Out:
# aspiration
# std      165
# turbo     36
# Name: count, dtype: int64

# %%
# area vs price
aspiration = df[['aspiration', 'price']]
aspiration
# Out:
#     aspiration    price
# 0          std  13495.0
# 1          std  16500.0
# 2          std  16500.0
# 3          std  13950.0
# 4          std  17450.0
# ..         ...      ...
# 196        std  16845.0
# 197      turbo  19045.0
# 198        std  21485.0
# 199      turbo  22470.0
# 200      turbo  22625.0
#
# [201 rows x 2 columns]

# %%
#indicator variables/dummy variables
#is a numerical variables used to label catoggories
dummy_variable_2 = pd.get_dummies(df['aspiration'])
dummy_variable_2.sample(5)
# Out:
#        std  turbo
# 40    True  False
# 107  False   True
# 148   True  False
# 199  False   True
# 12    True  False

# %%
dummy_variable_2.rename(columns={'std':'aspiration-std', 'turbo':'aspiration-turbo'},inplace= True)

dummy_variable_2.head()
# Out:
#    aspiration-std  aspiration-turbo
# 0            True             False
# 1            True             False
# 2            True             False
# 3            True             False
# 4            True             False

# %%
#merge data frame "df" and "dummy_variable_1"
df = pd.concat([df, dummy_variable_2], axis = 1)
# drop original column "fuel-type" from "df"
df.drop('aspiration', axis = 1, inplace= True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make num-of-doors   body-style  \
# 0          3                122  alfa-romero          two  convertible
# 1          3                122  alfa-romero          two  convertible
# 2          1                122  alfa-romero          two    hatchback
# 3          2                164         audi         four        sedan
# 4          2                164         audi         four        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...  city-mpg  \
# 0          rwd           front        88.6  0.811148  0.890278  ...        21
# 1          rwd           front        88.6  0.811148  0.890278  ...        21
# 2          rwd           front        94.5  0.822681  0.909722  ...        19
# 3          fwd           front        99.8  0.848630  0.919444  ...        24
# 4          4wd           front        99.4  0.848630  0.922222  ...        18
#
# ...

# %% [markdown]
# ### Analyzing Individual Feature Patterns using Visualization

# %%
#how to choosen right visualization method 
print(df.dtypes)
# Out:
# symboling               int64
# normalized-losses       int64
# make                   object
# num-of-doors           object
# body-style             object
# drive-wheels           object
# engine-location        object
# wheel-base            float64
# length                float64
# width                 float64
# height                float64
# curb-weight             int64
# engine-type            object
# num-of-cylinders       object
# engine-size             int64
# fuel-system            object
# bore                  float64
# stroke                float64
# compression-ratio     float64
# horsepower              int64
# peak-rpm              float64
# city-mpg                int64
# highway-mpg             int64
# price                 float64
# city-L/100km          float64
# highway-L/100         float64
# horsepower-binned    category
# fuel-type-diesel         bool
# fuel-type-gas            bool
# aspiration-std           bool
# aspiration-turbo         bool
# ...

# %% [markdown]
# ### continous numericsl variable

# %%
# 1. continous numerical variables

# are variables that may contain any value within some range
#can have datatypes int or float
#scatterplots with fitted liness

# %%
sns.regplot(x='engine-size', y='price', data=df)
plt.ylim(0,)
plt.title('correlation between engine size and price')
plt.show()

# %% [markdown]
# as the engine size goes up, the price goes up this indicates a postive direct correlation between two variables engine size seems like a pretty good predictor of price since the reg line is almost perfect digonal line

# %%
#examine the correlation
df[['engine-size', 'price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %% [markdown]
# a strong postive correlation

# %%
#highway-mpg
sns.regplot(x='highway-mpg', y='price', data=df)
plt.ylim(0,)
plt.title('correlation between engine size and price')
plt.show()

# %%
df[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
#as the highway-mpg increases the prices decreses this indicates a negative correlation between two variables
#highway-mpg could potentaially be used to predict price

# %%
sns.regplot(x='peak-rpm', y='price', data=df)
plt.ylim(0,)
plt.title('correlation between peak-rpm and price')
plt.show()

# %%
df[['peak-rpm', 'price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
#stroke
sns.regplot(x='stroke', y='price', data=df)
plt.ylim(0,)
plt.title('correlation between stroke and price')
plt.show()

# %%
df[['stroke', 'price']].corr()
# Out:
#           stroke     price
# stroke  1.000000  0.082269
# price   0.082269  1.000000

# %%
# 2. catogorical variables
#are variables that can take on one of a Limited, and usually fixed, number of possible values
# these variables that describe characteristics of a data unit and are selected from a small group of catagories can have the type object or int

# %%
df["body-style"].value_counts()
# Out:
# body-style
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
#box-plot for categorical variables

# %%
sns.boxplot(x="body-style", y = "price", data=df)
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %%
#body-style is not good predictor of price

# %%
sns.boxplot(x="engine-location", y = "price", data=df)
# Out:
# <Axes: xlabel='engine-location', ylabel='price'>

# %%
# drive-wheels
sns.boxplot(x="drive-wheels", y ="price", data=df)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %%
#make
sns.boxplot(x="make", y = "price", data=df)
# Out:
# <Axes: xlabel='make', ylabel='price'>

# %% [markdown]
# ### Descriptive Statistical Analysis

# %%
# describe() computes basic statistical for all cont variables
# np=on values are automatically skipped
# this will show
# count of the variable
# the mean
# std devation
# the min values
# the IQR(25%,50%,75%)
# the max

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean     0.899108  2555.666667   126.875622    3.330692    3.256874
# std      0.040933   517.296727    41.546834    0.268072    0.316048
# ...

# %%
df.describe(include=['object'])
# Out:
#           make num-of-doors body-style drive-wheels engine-location  \
# count      201          201        201          201             201
# unique      22            2          5            3               2
# top     toyota         four      sedan          fwd           front
# freq        32          115         94          118             198
#
#        engine-type num-of-cylinders fuel-system
# count          201              201         201
# unique           6                7           8
# top            ohc             four        mpfi
# freq           145              157          92

# %%
df.describe(include='all')
# Out:
#          symboling  normalized-losses    make num-of-doors body-style  \
# count   201.000000          201.00000     201          201        201
# unique         NaN                NaN      22            2          5
# top            NaN                NaN  toyota         four      sedan
# freq           NaN                NaN      32          115         94
# mean      0.840796          122.00000     NaN          NaN        NaN
# std       1.254802           31.99625     NaN          NaN        NaN
# min      -2.000000           65.00000     NaN          NaN        NaN
# 25%       0.000000          101.00000     NaN          NaN        NaN
# 50%       1.000000          122.00000     NaN          NaN        NaN
# 75%       2.000000          137.00000     NaN          NaN        NaN
# max       3.000000          256.00000     NaN          NaN        NaN
#
#        drive-wheels engine-location  wheel-base      length       width  ...  \
# ...

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %%
#grouping data # pivot 

drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.rename(columns={'drive-wheels':'value_counts'},inplace=True)
drive_wheels_counts.index.name='drive-wheels'
drive_wheels_counts
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %%
engine_location_counts = df['engine-location'].value_counts().to_frame()
engine_location_counts.rename(columns={'engine-location':'vakue_counts'}, inplace = True)
engine_location_counts.index.name="engine-location"
engine_location_counts
# Out:
#                  count
# engine-location
# front              198
# rear                 3

# %%
# examining the value_counts of the engine location would not be a good predictor variable for the price
# this is because there are only two values for this variable and the distribution is highly imbalanced with majority of cars having front engine location
# skewed data can lead to biased model predictions and reduced model performance.
# thus we r not going to use this variable for our analysis

# %% [markdown]
# ###     Basics of grouping

# %%
# groupby method is groups the data by different catogories. the data is grouped baswed on one or several variable qnd 
# analysis is performed on the individual group

# %%
df['drive-wheels'].unique().tolist()
# a vehicle drive-wheels is the wheel tire assembly that actually pushes or pulls the veh down the road
# Out:
# ['rwd', 'fwd', '4wd']

# %%
#which type of drive wheels is most valuable
df_group_one = df[['drive-wheels', 'body-style', 'price']]
df_group_one = df_group_one.groupby(['drive-wheels'], as_index=False).mean(numeric_only=True)
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
 #which type of drive wheels is most valuable
df_gptset = df[['drive-wheels', 'body-style', 'price']]
grouped_test = df_gptset.groupby(['drive-wheels', 'body-style'], as_index=False).mean()
grouped_test
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
# pivot table means creating a spreadsheet-style table that summarizes data by aggregating values based on specified rows and columns
pivot_table = df.pivot_table(values='price', index='drive-wheels', columns='body-style')
pivot_table
# Out:
# body-style    convertible       hardtop     hatchback         sedan  \
# drive-wheels
# 4wd                   NaN           NaN   7603.000000  12647.333333
# fwd               11595.0   8249.000000   8396.387755   9811.800000
# rwd               23949.6  24202.714286  14337.777778  21711.833333
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
pivot_table= pivot_table.fillna(0)
pivot_table
# Out:
# body-style    convertible       hardtop     hatchback         sedan  \
# drive-wheels
# 4wd                   0.0      0.000000   7603.000000  12647.333333
# fwd               11595.0   8249.000000   8396.387755   9811.800000
# rwd               23949.6  24202.714286  14337.777778  21711.833333
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
 #which type of drive wheels is most valuable
df_gptset = df[['body-style', 'price']]
grouped_test = df_gptset.groupby(['body-style'], as_index=False).mean()
grouped_test
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
plt.pcolor(pivot_table, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
# heatmap is a data visualization technique that uses color-coding to represent different values in a matrix
plt.pcolor(pivot_table, cmap='RdBu')

# %%
#default labels convey no info , so change lable
pivot_table.index
# Out:
# Index(['4wd', 'fwd', 'rwd'], dtype='object', name='drive-wheels')

# %%
fig,ax = plt.subplots()
im=ax.pcolor(pivot_table, cmap='RdBu')
# labels names
row_lables = pivot_table.columns # accessing bodytype from grouped pivot
col_labels = pivot_table.index # acessing drive wheels from grouped pivot
#move ticks and lables to the center

ax.set_xticks(np.arange(pivot_table.shape[1]) +0.5, minor = False)
ax.set_yticks(np.arange(pivot_table.shape[0]) +0.5, minor = False)
#insert labels
ax.set_xticklabels(row_lables, minor = False)
ax.set_yticklabels(col_labels, minor = False)


#rotate the x lables to see better
plt.xticks(rotation=90)
fig.colorbar(im)
plt.show()
